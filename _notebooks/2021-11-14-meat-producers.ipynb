# %% [markdown]
# # Inspecting meat producers data
# > We'll use SQL examine data to assess its quality and how to modify data and tables to make analysis easier.
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - categories: [sql, postgresql]
# - hide: false

# %% [markdown]
# There are a lot of times when data analysts receive dirty data - filled with errors an no structure. The data could contain errors, missing values, poor organization, typos or spelling mistakes. In order to analyze it, we need to modify it in some way.

# %%
# %load_ext sql
import os

host = "localhost"
database = "analysis"
user = os.getenv('SQL_USER')
password = os.getenv('SQL_PASSWORD')

connection_string = f"postgresql://{user}:{password}@{host}/{database}"
# %sql $connection_string
# Out:
# 'Connected: postgres@analysis'

# %% [markdown]
# ---
# ### Importing the Data
# We'll use a directory of U.S. meat, poultry, and egg producers. The Food Safety and Inspection Service (FSIS), an agency within the U.S. Department of Agriculture, compiles and updates this database every month. The FSIS is responsible for inspecting animals and food at more than 6,000 meat processing plants, slaughterhouses, farms, and the like.

# %%
# %%sql
# CREATE TABLE meat_poultry_egg_inspect (
#     est_number varchar(50) CONSTRAINT est_number_key PRIMARY KEY,
#     company varchar(100),
#     street varchar(100),
#     city varchar(30),
#     st varchar(2),
#     zip varchar(5),
#     phone varchar(14),
#     grant_date date,
#     activities text,
#     dbas text
# );
#
# COPY meat_poultry_egg_inspect
# FROM 'C:\Users\Public\postgresql_practice\practical-sql-master\Chapter_09\MPI_Directory_by_Establishment_Name.csv'
# WITH (FORMAT CSV, HEADER, DELIMITER ',');
#
# CREATE INDEX company_idx ON meat_poultry_egg_inspect (company);
# Out:
#  * postgresql://postgres:***@localhost/analysis
# Done.
# 6287 rows affected.
# Done.
# []

# %%
# %%sql
# SELECT * FROM meat_poultry_egg_inspect
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 10 rows affected.
# [('M46712+P46712', '121 In-Flight Catering LLC', '45 Rason Road', 'Inwood', 'NY', '11096', '(718) 663-4612', datetime.date(2016, 6, 27), 'Meat Processing, Poultry Processing', None),
#  ('M13561+P13561', '165368 C. Corporation ', '5617 Hoover Street, Suite A', 'Houston', 'TX', '77092', '(713) 263-1944', datetime.date(2014, 6, 30), 'Meat Processing', 'Long Phung Food Products'),
#  ('M46724+P46724', '1732 Meats LLC', '6250 Baltimore Pike', 'Yeadon', 'PA', '19050', '(267) 879-7214', datetime.date(2015, 9, 8), 'Meat Processing, Poultry Processing', None),
#  ('M7067+P7067', '1st Original Texas Chili Company, Inc.', '3313 N. Jones Street', 'Fort Worth', 'TX', '76106', '(817) 626-0983', datetime.date(2003, 11, 28), 'Meat Processing', 'T.C. Foods; Texas Chili'),
#  ('M48225', '290 West Bar & Grill', '12013 HWY 290 West', 'Austin', 'TX', '78737', '(512) 963-8963', datetime.date(2016, 11, 1), 'Meat Processing', 'Afia Foods'),
#  ('M17530+P17530', '3 Little Pigs LLC', '625 South Main Street', 'Wilkes Barre', 'PA', '18701', '(570) 823-9778', datetime.date(2016, 3, 23), 'Meat Processing, Poultry Processing', 'House of Bricks'),
#  ('M19035+P19035', '3-A Enterprises', 'P.O. Box 592', 'Carroll', 'IA', '51401', '(712) 792-5909', datetime.date(1994, 6, 15), 'Meat Processing, Poultry Processing', 'Party Time Fundraising'),
#  ('M45790', '3282 Beaver Meadow Road LLC', '3282 Beaver Meadow Road', 'Sharon', 'VT', '5065', '(802) 763-2333', datetime.date(2016, 3, 10), 'Meat Processing, Meat Slaughter', 'Royalton Meats; Sharon Beef'),
#  ('M45377', '3D Meats, LLC', '14740 E. Lincoln Way', 'Dalton', 'OH', '44618', '(330) 985-0311', datetime.date(2015, 2, 20), 'Meat Processing, Meat Slaughter', None),
#  ('M22017+P22017+V22017', '4 Frendz Meat Market', '1342 Bridge St.', 'Clarkston', 'WA', '99403', '(509) 751-9888', datetime.date(2010, 8, 19), 'Animal Foods Inspection, Meat Processing, Poultry Processing, Voluntary Processing - Meat', 'Southfork Sausage')]

# %% [markdown]
# The `meat_poultry_egg_inspect` table has 10 columns. We add a natural primary key constraint to the `est_number` column, which contains a unique value for each row that identifies the establishment. Most of the other columns relate to the company's name and location. We set the `activities` and `dbas` columns to `text` data type since some of the strings in the columns are thousands of characters long. We create an index on the `company` column to speed up searches for particular companies.
#
# Let's use the `count()` aggregate function  to check how many rows are in the table.

# %%
# %%sql
# SELECT count(*) FROM meat_poultry_egg_inspect;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 1 rows affected.
# [(6287,)]

# %% [markdown]
# There are 6,287 rows in the table.

# %% [markdown]
# ---
# ### Interviewing the Data Set
#
# Let's interview the data set to expose its limitations and raise some questions.
#
# #### Checking for Duplicates
#
# We might assume that each company in each row operates at a distinct address. But it's never safe to assume anything in data analysis, so let's check if that is true.

# %%
# %%sql
# SELECT company, street, city, st, count(*) AS address_count
# FROM meat_poultry_egg_inspect
# GROUP BY company, street, city, st
# HAVING count(*) > 1
# ORDER BY company, street, city, st;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 23 rows affected.
# [('Acre Station Meat Farm', '17076 Hwy 32 N', 'Pinetown', 'NC', 2),
#  ('Beltex Corporation', '3801 North Grove Street', 'Fort Worth', 'TX', 2),
#  ('Cloverleaf Cold Storage', '111 Imperial Drive', 'Sanford', 'NC', 2),
#  ('Crete Core Ingredients, LLC', '2220 County Road I', 'Crete', 'NE', 2),
#  ('Crider, Inc.', '1 Plant Avenue', 'Stillmore', 'GA', 3),
#  ('Dimension Marketing & Sales, Inc.', '386 West 9400 South', 'Sandy', 'UT', 2),
#  ('Foster Poultry Farms, A California Corporation', '6648 Highway 15 North', 'Farmerville', 'LA', 2),
#  ('Freezer & Dry Storage, LLC', '21740 Trolley Industrial Drive', 'Taylor', 'MI', 2),
#  ('JBS Souderton Inc.', '249 Allentown Road', 'Souderton', 'PA', 2),
#  ('KB Poultry Processing LLC', '15024 Sandstone Dr.', 'Utica', 'MN', 2),
#  ('Lakeside Refrigerated Services', '2600 Oldmans Creek Road', 'Swedesboro', 'NJ', 2),
#  ('Liberty Cold Storage', '1310 Remington Blvd.', 'Bolingbrook', 'IL', 2),
#  ('M.G. Waldbaum Company', '120 Tower Street', 'Gaylord', 'MN', 3),
#  ('Midway International Logistics LLC', '948 Bradley Street', 'Watertown', 'NY', 2),
#  ('Nordic Logistics and Warehousing, LLC', '220 Nordic Way', 'Pooler', 'GA', 2),
#  ('OK Foods, Inc.', '3921 Reed Lane', 'Fort Smith', 'AR', 2),
#  ('Pacific Produce Corporation', '220 East Harmon Industrial Park Road', 'Tamuning', 'GU', 2),
#  ('Payless Distribution Center (PDC)', '370 Mendioka Street', 'Dededo', 'GU', 2),
#  ('Piatkowski Riteway Meats Inc.', '3555 Witmer Road', 'Niagara Falls', 'NY', 2),
#  ('Preferred Freezer Services', '2700 Trade Street', 'Chesapeake', 'VA', 2),
#  ('THE AMERICAN PIG', '25 MEADOW ROAD', 'ASHEVILLE', 'NC', 2),
#  ('The Classic Jerky Company', '21655 Trolley Industrial Drive', 'Taylor', 'MI', 2),
#  ('United States Cold Storage Inc.', '11801 NW 102 Road', 'Medley', 'FL', 2)]

# %% [markdown]
# Here we grouped companies by unique combinations of the `company`, `street`, `city`, and `st` columns. Then we use `count(*)`, which returns the number of rows for each combination of those columns and gives it the alias `address_count`. Using the `HAVING` clause, we filter the results only to show cases where more than one row has the same combination of values. This should return all duplicate addresses for a company.
#
# ![3.png](attachment:3.png)
#
# The query returns 23 rows, which means there are 23 cases where the same company is listed multiple times at the same address. This might not necessarily be a problem. There may be valid reasons for a company to appear multiple times at the same address. For example, tow types of processing plants could exist with the same name. On the other hand, we may have found data entry errors. Either way, this is good to know for any conclusions in the future.

# %% [markdown]
# #### Checking for Missing Values
#
# Let's start checking for missing values by asking a basic question: how many of the meat, poultry, and egg processing companies are in each state? Finding out whether we have values from all states and whether any rows are missing a state code will serve as another useful check on the data.

# %%
# %%sql
# SELECT st, count(*) AS st_count
# FROM meat_poultry_egg_inspect
# GROUP BY st
# ORDER BY st;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 57 rows affected.
# [('AK', 17),
#  ('AL', 93),
#  ('AR', 87),
#  ('AS', 1),
#  ('AZ', 37),
#  ('CA', 666),
#  ('CO', 121),
#  ('CT', 55),
#  ('DC', 2),
#  ('DE', 22),
#  ('FL', 322),
#  ('GA', 206),
#  ('GU', 14),
#  ('HI', 47),
#  ('IA', 149),
#  ('ID', 38),
#  ('IL', 348),
#  ('IN', 82),
#  ('KS', 69),
#  ('KY', 110),
#  ('LA', 49),
#  ('MA', 101),
#  ('MD', 75),
#  ('ME', 24),
#  ('MI', 177),
#  ('MN', 160),
#  ('MO', 158),
#  ('MP', 4),
#  ('MS', 69),
#  ('MT', 23),
#  ('NC', 212),
#  ('ND', 22),
#  ('NE', 110),
#  ('NH', 18),
#  ('NJ', 244),
#  ('NM', 28),
#  ('NV', 35),
#  ('NY', 346),
#  ('OH', 186),
#  ('OK', 59),
#  ('OR', 86),
#  ('PA', 364),
#  ('PR', 84),
#  ('RI', 27),
#  ('SC', 55),
#  ('SD', 24),
#  ('TN', 113),
#  ('TX', 387),
#  ('UT', 71),
#  ('VA', 111),
#  ('VI', 2),
#  ('VT', 27),
#  ('WA', 139),
#  ('WI', 184),
#  ('WV', 23),
#  ('WY', 1),
#  (None, 3)]

# %% [markdown]
# When you run the query, it tallies the number of times each state postal code `st` appears in the table.
#
# But the result shows 57 states when there are only 50 states in the U.S. That's because the data also incorporates U.S. territories.
# The state with the highest number of establishments is Alaska (AK). However, the row at the bottom has a `st` of `null` and a count of 3. Let's find out these null values using `count()` with `GROUP BY`.

# %%
# %%sql
# SELECT est_number, company, city, st, zip
# FROM meat_poultry_egg_inspect
# WHERE st IS NULL;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 3 rows affected.
# [('V18677A', 'Atlas Inspection, Inc.', 'Blaine', None, '55449'),
#  ('M45319+P45319', 'Hall-Namie Packing Company, Inc', None, None, '36671'),
#  ('M263A+P263A+V263A', 'Jones Dairy Farm', None, None, '53538')]

# %% [markdown]
# These are the establishments with a null value in the `st` column.

# %% [markdown]
# #### Checking for Inconsistent Data Values
# We can check for inconsistently entered data within a column by using `GROUP BY` with `count()`. Many of the 6,200 companies in our table are multiple
# locations owned by a few multinational food corporations, such as Cargill
# or Tyson Foods. To find out how many locations each company owns, we
# would try to count the values in the `company` column.

# %%
# %%sql
# SELECT company, count(*) AS company_count
# FROM meat_poultry_egg_inspect
# GROUP BY company
# ORDER BY company ASC;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 5586 rows affected.
# [('121 In-Flight Catering LLC', 1),
#  ('165368 C. Corporation ', 1),
#  ('1732 Meats LLC', 1),
#  ('1st Original Texas Chili Company, Inc.', 1),
#  ('290 West Bar & Grill', 1),
#  ('3-A Enterprises', 1),
#  ('3 Little Pigs LLC', 1),
#  ('3282 Beaver Meadow Road LLC', 1),
#  ('3D Meats, LLC', 1),
#  ('4-L Processing', 1),
#  ('4 Frendz Meat Market', 1),
#  ('41 Market', 1),
#  ('412 Meat Processing Inc.', 1),
#  ('458 1/2 South Broadway Meat Inc', 1),
#  ('4G Meat Processing LLC', 1),
#  ('50th State Poultry', 1),
#  ('58 Place Seafood Inc.', 1),
#  ('5th Generation Adams Farm', 1),
#  ('701 Foods, Inc.', 1),
#  ('814 Americas, Inc.', 1),
#  ('86-17 Northern Blvd. Corp.', 1),
#  ('888 Food Company', 1),
#  ('A-1 Meat Inc.', 1),
#  ('A & A Finest', 1),
#  ('A & A Halal Distributors', 1),
#  ('A & B Famous Gefilte Fish Inc.', 1),
#  ('A & G Food Service LLC', 1),
#  ('A & M Cold Storage', 1),
#  ('A & R Packing Co., Inc.', 1),
#  ('A & S Distributors', 1),
#  ('A & S Produce Inc.', 1),
#  ('A Casa Enterprises LLC', 1),
#  ('A Full Measure Catering', 1),
#  ('A G Specialty Foods', 1),
#  ('A La Carte Foods, Inc.', 1),
#  ("A To Z Kosher Meat Prod's In", 1),
#  ('A to Z Portion Control Meats, Inc.', 1),
#  ('A&M Packing LLC', 1),
#  ('A&S & Son', 1),
#  ('A&W Country Meats, Inc.', 1),
#  ('A. Altieri & Sons', 1),
#  ('A. Concepcion Hnos', 1),
#  ('A. Decoite Packing House, Inc.', 1),
#  ('A. F. Wendling, Inc.', 1),
#  ('A. Gemmen & Sons, Inc.', 1),
#  ('A. Gimenez Trading LLC', 1),
#  ('A. I. Foods', 1),
#  ('A. N. Deringer, Inc.', 2),
#  ('A. S. K. Foods Inc.', 1),
#  ('A. Tarantino & Sons', 1),
#  ('A.A. Rubashkin & Sons', 1),
#  ('A.B. Vannoy Hams', 1),
#  ('A.F.I. Food Service L.L.C.', 1),
#  ("A.J.'s Lena Maid Meats, Inc.", 1),
#  ("A.J. Cetak's Meat Market", 1),
#  ('A.J. Sons, Inc.', 1),
#  ('A.L. Beck & Sons, Inc.', 1),
#  ('A.N. Deringer Inc.', 1),
#  ('A.N. Deringer, Inc.', 1),
#  ('A.S.K. Foods Inc.', 1),
#  ('A.T.A. Meat Company, Inc.', 1),
#  ('AA Meat Products Inc.', 2),
#  ('AA Poultry Processing, LLC', 1),
#  ('Aala Meat Market, Inc.', 1),
#  ('Abanto Forwarding, Inc.', 1),
#  ('Abattoir Associates Inc.', 1),
#  ("Abbott's Meat, Inc.", 1),
#  ('Abbyland Foods, Inc.', 2),
#  ('Abbyland Pork Pack, Inc.', 1),
#  ("Abe's Finest Meats", 1),
#  ("Abe's Kosher Meats LLC", 1),
#  ('Abeles & Heymann, LLC', 1),
#  ('ABF Packing, Inc.', 1),
#  ('Able Freight Services Inc.', 1),
#  ('Abner Snack Foods, Inc.', 2),
#  ('Abuelito Meat Inc.', 1),
#  ('Abundant Foods', 1),
#  ('Academy Packing Co Inc', 1),
#  ('Acadian Fine Foods, LLC', 1),
#  ('ACC Central Kitchen LLC', 1),
#  ('Accu-Ray Inspection Services', 1),
#  ('Achatz Handmade Pie Company LLC', 1),
#  ('Achatz Soup From Skratzch', 1),
#  ('Acme Delivery Service', 1),
#  ('ACME Jerky, LLC', 1),
#  ('Acoreana Manufacturing, Co.', 1),
#  ('Acre Station Meat Farm', 2),
#  ('Activ International, Inc.', 1),
#  ('Ada Valley Gourmet Foods', 1),
#  ('Adam Farms, LLC', 1),
#  ('Adams Farm Slaughterhouse LLC', 1),
#  ("Addielee's Inc.", 1),
#  ('Adena Poultry', 1),
#  ('Adesa International LLC', 1),
#  ('Adirondack Meat Co.', 1),
#  ("Adolf's Meat Products", 1),
#  ('Advance Pierre Foods, Inc', 2),
#  ('Advance Pierre Foods, Inc.', 1),
#  ('AdvancePierre Foods', 1),
#  ('AdvancePierre Foods, Inc', 1),
#  ('AdvancePierre Foods, Inc.', 7),
#  ('Advertising Resources, Inc', 1),
#  ('Afandina Halal', 1),
#  ('AFS Classico, LLC', 1),
#  ('Afya Brands International, Inc.', 1),
#  ('AG Food Products Corp.', 1),
#  ('AGA Investments Inc.', 1),
#  ('Against The Grain Gourmet', 1),
#  ('Agri Star Meat and Poultry, LLC', 1),
#  ('Agro Merchant Group Inc.', 1),
#  ('Agro Merchants Group Charleston LLC', 1),
#  ('AGRO Merchants Oakland LLC', 2),
#  ('AGRO Merchants Oakland, LLC', 1),
#  ('Airfrigo USA Inc/Seafrigo Coldstorage Fairmont', 1),
#  ('Ajinomoto Toyo Frozen Noodle, Inc.', 1),
#  ('Ajinomoto Windsor Inc.', 2),
#  ('Ajinomoto Windsor, Inc.', 7),
#  ('Ajuua', 1),
#  ("Al's Hickory House BBQ", 1),
#  ("Al's Wholesale Meats, Inc.", 1),
#  ('Al-Marwa L. L. C.', 1),
#  ('Al - Baghdadi Food Inc.', 1),
#  ('Al & John Inc.', 1),
#  ("Al Lunardi & Son's Meat Co Inc", 1),
#  ('Al Shabrawy Inc.', 1),
#  ('Alabama CatfishLLC', 1),
#  ('Alaska Commercial Co.', 1),
#  ('Alaska Natural Meats, Ltd.', 1),
#  ('Alaska Sausage Company, Inc.', 1),
#  ('Alatrade Foods', 2),
#  ('Alatrade Foods LLC', 1),
#  ('Alba Cold Storage', 1),
#  ('Albert Lea Select Foods Inc.', 1),
#  ("Alberto's Meat Shop", 1),
#  ('Albertville Quality Foods', 2),
#  ("Albie's Foods, Inc.", 1),
#  ('Albion Locker', 1),
#  ('Alcor Foods, Inc.', 1),
#  ('Alderfer, LLC', 1),
#  ('Aldon Food Corporation', 1),
#  ('AleCon Enterprises Inc.', 1),
#  ('Alef Sausage', 1),
#  ('Alena Foods', 1),
#  ("Alewel's Country Meats", 1),
#  ("Alex's Deli", 1),
#  ("Alex's Meat & Provision", 1),
#  ('Alex & George Wholesale Meats, Inc.', 1),
#  ('Alex Froehlich Packing Company', 1),
#  ("Alexander's Ham Co.", 1),
#  ('Alexander & Hornung', 1),
#  ('Alexandra Foods', 1),
#  ('Alexis Wholesale Inc.', 1),
#  ('ALFREDO AIELLO ITALIAN FOODS, INC.', 1),
#  ('Alfresco Pasta, LLC', 1),
#  ('Ali International Inc.', 1),
#  ('All American Cold Storage', 1),
#  ('All American Meats, Inc.', 1),
#  ('All Foods LLC', 1),
#  ("All People's Food", 1),
#  ('Alle-Pia', 1),
#  ('Alleghany Highlands Agricultural Center, LLC', 1),
#  ('Allen Brothers, Inc', 1),
#  ('Allen Harim Foods, LLC.', 1),
#  ('Allentown Refrigerated Terminals Inc.', 1),
#  ('Allied Caribbean Distribution', 1),
#  ('Allied Frozen Storage inc.', 1),
#  ('Allied Poultry Sales Co., Inc.', 1),
#  ('Allonco Inc.', 1),
#  ('Alma Cold Storage, Inc.', 1),
#  ('Alma Foods, LLC', 1),
#  ('Almi Inc.', 1),
#  ('Alpha Foods Co.', 1),
#  ('Alpha Omega Distributors, LTD', 1),
#  ('Alpine Meats Inc.', 1),
#  ('Alpine Sausage Company', 1),
#  ('Alta Vista Locker', 1),
#  ('Alto Valle Foods, Inc.', 1),
#  ('Amana Meat Shop & Smokehouse', 1),
#  ('Amaro Foods Enterprise Inc', 1),
#  ('Amba Ham Company Inc.', 1),
#  ('AmBar Foods', 1),
#  ('Ambassador Meat Dist. Inc.', 1),
#  ('Amboy Group, LLC', 1),
#  ('Amend Packing Co.', 1),
#  ("America's Best Steak", 1),
#  ("America's Catch Inc", 1),
#  ("America's Custom Brokers, Inc.", 1),
#  ('America New York Ri Wang Food Group', 1),
#  ('American Alliance Partners LLC', 1),
#  ('American Beef Packers, Inc.', 1),
#  ('American Butchers, Inc.', 1),
#  ('American Butchers, LLC', 1),
#  ('American Cold Storage', 4),
#  ('American Cold Storage-IN. Div.', 1),
#  ('American Consolidation & Logistics', 1),
#  ('American Custom Meats LLC', 1),
#  ('American Egg Products, LLC', 1),
#  ('American Food Export Service', 1),
#  ('AMERICAN FOOD SERVICE', 1),
#  ('American Food Services, LLC', 1),
#  ('American Food Supplies LLC', 1),
#  ('American Food Systems Inc.', 1),
#  ('American Halal Meat', 1),
#  ('American Halal Meat Inc.', 1),
#  ('American Kitchen Delights Inc.', 1),
#  ('American Laboratories, Inc', 1),
#  ('American Laboratories, Inc.', 2),
#  ('American Meat Company', 1),
#  ('American Meat Processing Co., Inc.', 1),
#  ('American Outdoor Products, Inc', 1),
#  ('American Pasteurization Co LLC', 1),
#  ('American Pasteurization Company', 1),
#  ('American Samoa Government', 1),
#  ('American Skin Food Group LLC', 1),
#  ('American Soy Products, Inc.', 1),
#  ('American Specialty Food, Inc.', 1),
#  ('Americold', 11),
#  ('Americold - Ontario, Oregon', 1),
#  ('Americold Corporation', 2),
#  ('Americold Logistics', 21),
#  ('AmeriCold Logistics', 7),
#  ('AmeriCold Logistics Crete Dist', 1),
#  ('Americold Logistics Inc', 2),
#  ('Americold Logistics Inc.', 1),
#  ('Americold Logistics LLC', 8),
#  ('Americold Logistics, Inc.', 3),
#  ('AmeriCold Logistics, Inc.', 1),
#  ('Americold Logistics, LLC', 9),
#  ('AmeriCold Logistics, LLC', 2),
#  ('Americold Logistics, LLC.', 1),
#  ('Americold, LLC', 1),
#  ('Ameripack Foods LLC', 1),
#  ('AmeriQual Group, LLC', 1),
#  ('AmeriQual Packaging', 1),
#  ('Ameristar Meats, Inc', 1),
#  ('Ameristar Meats, Inc.', 2),
#  ('Amick Farms, LLC', 1),
#  ('AMICK FARMS, LLC', 1),
#  ("Amigo's Mexican Foods", 1),
#  ('Amigos Frozen Solutions', 1),
#  ('Amilas Foods', 1),
#  ('Aminchi Foods International, Inc.', 1),
#  ('Amity Packing Co. Inc.', 1),
#  ('Amor Nino Foods, Inc.', 1),
#  ('AMPC, Inc.', 2),
#  ('Amy Food Inc.', 1),
#  ('Anchor Distribution Service, Inc.', 1),
#  ('Anco Poultry Processing', 1),
#  ('Anderson Boneless Beef, Inc.', 1),
#  ('Anderson Produce Company, Inc.', 1),
#  ('Andrade Slaughterhouse', 1),
#  ("Andy's Deli & Mikolajczk", 1),
#  ("Andy's Meats Inc.", 1),
#  ('Angelina Foods', 1),
#  ('Angus Meats, Inc.', 1),
#  ("Angy's Landolfi Food Group LLC", 1),
#  ('Anichini Bros Inc', 1),
#  ('Ankeny Cold Storage, LLC', 1),
#  ("Anna's Kitchen, Inc.", 1),
#  ('Annex Food Company', 1),
#  ('Ansaldos Sausage Corp.', 1),
#  ('Antonio Pena Distributors', 1),
#  ('Apache Foods LLC', 1),
#  ('Apex Cold Storage', 1),
#  ('Apex Cold Storage Co.', 1),
#  ('Apollo Ship Chandlers Inc.', 1),
#  ('Apostolic Christian World Relief', 1),
#  ('Appalachian Meats LLC', 1),
#  ('Appalachian Meats, LLC', 1),
#  ('Appalachian Smoked Meats', 1),
#  ('Appetito Provisions Co Inc', 1),
#  ('Apple Valley Farms', 1),
#  ('Applied Process Systems', 1),
#  ('Aquasouth', 1),
#  ('Ara Food Corp.', 1),
#  ('Arapahoe Foods Inc.', 1),
#  ('ARC Industries', 1),
#  ('Arch Foods Inc', 1),
#  ("Archie's Foods, Inc.", 1),
#  ('Arck Foods, Inc.', 1),
#  ('Arctic Cold Storage', 1),
#  ('Arctic Foods Inc', 1),
#  ('Arctic Frozen Foods LLC', 1),
#  ('Arctic Logistics LLC', 1),
#  ('Argo Merchants Oakland', 1),
#  ('Argus Food Processing Corporation', 1),
#  ('Ariake USA, Inc.', 1),
#  ('Aries Prepared Beef Co.', 1),
#  ('Aristocrat Products, Inc', 1),
#  ('Arkansas Department of Corrections', 1),
#  ('Arkansas Refrigerated Services', 2),
#  ('Arko Veal Company, Inc.', 1),
#  ('Arlindo Catering Inc.', 1),
#  ('Arm National Foods', 1),
#  ('Armour-Eckrich Meats LLC', 3),
#  ('Armour-Eckrich Meats, Inc.', 1),
#  ('Armour-Eckrich Meats, LLC', 2),
#  ('Armour - Eckrich Meats, LLC', 1),
#  ("Arnold's & Eddies Foods Inc.", 1),
#  ('Arsho Meat Products', 1),
#  ('Artisan Bread Co., LLC', 1),
#  ('Arveybell Farm Co.', 1),
#  ('Aryzta LLC', 2),
#  ('Asahi Foods Inc.', 1),
#  ('Asheville Packing Co.', 1),
#  ('Ashland Cold Storage Co.', 1),
#  ('Ashland Cold Storage Company', 1),
#  ('Ashland Sausage Company', 1),
#  ('Ashley Foods Inc.', 1),
#  ('Ashton Farms Custom Meats', 1),
#  ('Asiago Foods-USA, Inc.', 1),
#  ('Asianic Inc.', 1),
#  ('Aspen Foods Div Koch Meat Co.', 1),
#  ('Aspen Hollow Sheep Station Mobile Harvest Unit', 1),
#  ('Assemblers Inc.', 1),
#  ('Associated Brands Inc.', 1),
#  ('Associated Grocers of FL', 1),
#  ('Astra Foods Inc.', 1),
#  ('ASU Food Safety and Product Development Lab', 1),
#  ('At Last! Gourmet Foods', 1),
#  ('ATG Transportation LLC', 1),
#  ('Athena Foods', 1),
#  ('Athens Foods, Inc.', 1),
#  ('Athens Sausage Co.', 1),
#  ('ATK Foods, Inc.', 1),
#  ('Atkins Sheep Ranch Inc.', 1),
#  ('Atkins Sheep Ranch, Inc.', 1),
#  ('Atlanta Meat Company, Inc.', 1),
#  ('Atlanta Sausage Company', 1),
#  ('Atlantic Coast Freezers LLC', 1),
#  ('Atlantic Coast Freezers, LLC', 1),
#  ('Atlantic Veal & Lamb Inc', 1),
#  ('Atlantic Veal & Lamb LLC', 1),
#  ('Atlas Inspection, Inc.', 1),
#  ('Atlas Meat Company', 1),
#  ('ATM International USA, Inc.', 1),
#  ('ATPAC Inc.', 1),
#  ('Attilio Esposito Inc.', 1),
#  ('Au Bon Canard Foie Gras, Inc.', 1),
#  ('AU, LAU and Associates, Inc.', 1),
#  ('Aufschnitt Meats (W & L Kosher Meats)', 1),
#  ("Augustine's Italian Village Inc.", 1),
#  ("Aunt Kitty's Foods Inc", 1),
#  ('Aurnish Enterprises Corp.', 1),
#  ('Aurora Packing Company, Inc.', 1),
#  ('Authentic Brands of Chicago', 1),
#  ('AVA Pork Products, Inc.', 1),
#  ('Avalanche Cheese Company', 1),
#  ('Avalon Meat Candy, LLC', 1),
#  ('Avanti Foods', 1),
#  ('Avenal State Prison', 1),
#  ('AVF Holding LLC', 1),
#  ('Ayrshire Farm Management, LC', 1),
#  ('Ayrshire Farm Management, LLC', 1),
#  ('AZ Gourmet Foods Inc.', 1),
#  ('AZ Grass Fed Beef', 1),
#  ('Az Grass Raised Bone Broth', 1),
#  ('Azar and Company', 1),
#  ('Aztec Imperio', 1),
#  ('B & G Foods, Inc. Distribution Center', 1),
#  ('B & G Foods, North America, Inc.', 1),
#  ('B & H Foods, Inc.', 1),
#  ('B & K Meat', 1),
#  ('B & M Provisions', 1),
#  ('B & R Bierocks, Inc.', 1),
#  ('B & R Meat Processing', 1),
#  ('B & S Food Products', 1),
#  ('B&B Food Products', 1),
#  ('B&B Poultry Co., Inc.', 1),
#  ('B&G Foods, Inc.', 2),
#  ('B&G Meats Inc.', 1),
#  ('B&M Processing', 1),
#  ('B&O Island Style Chamorro Sausage', 1),
#  ('B&P Quality Meats', 1),
#  ('B&R Quality Meats', 1),
#  ('B. Joszt Inc.', 1),
#  ('B.W.J.W. Inc.', 1),
#  ('Babybeef USA Corp.', 1),
#  ('Bach Cuc Beef Jerky, Inc', 1),
#  ('Bachetti Bros. Market', 1),
#  ('Badalamente Sausage Co.', 1),
#  ('Badger Boiled Ham Co., Inc.', 1),
#  ("Baffo's Enterprises", 1),
#  ("Baffoni's Poultry Farm Inc.", 1),
#  ('BAFS, Inc.', 1),
#  ('Bagel Bites', 1),
#  ('Baily International', 1),
#  ('Baily International Inc.', 1),
#  ('Baily Meat', 1),
#  ('Baja Foods, LLC', 1),
#  ('Baja Frige Inc.', 1),
#  ('Baja Frige, Inc.', 1),
#  ('Bak Foods', 1),
#  ('Bakalars Sausage Co., Inc.', 1),
#  ('Baker River Deer Farm', 1),
#  ('Baker, Inc.', 1),
#  ('Bakkavor Foods USA, Inc', 1),
#  ('Bakkavor Foods USA, Inc.', 1),
#  ('Bakkavor Foods, USA Inc.', 1),
#  ('Balaton Food Inc.', 1),
#  ('Balkan Meat Market Inc.', 1),
#  ('Ballas Egg Products Corporation', 1),
#  ('Ballester Hermanos Inc.', 1),
#  ('Ballester Hermanos, Inc.', 1),
#  ('Bally United Produce, LTD', 1),
#  ('Balter Meat Co.', 1),
#  ('Bama Sea Products', 1),
#  ('Bangkok Meatball Co.', 1),
#  ('Bangkok Meatball Corp. #2', 1),
#  ('Banner Creek, LLC', 1),
#  ('Bar-S Foods Co.', 2),
#  ('Bar-S Foods Company', 2),
#  ('Barakah Kabab Inc.', 1),
#  ('Barbarossa LLC', 1),
#  ('Baretta Provision Inc', 1),
#  ('Baringer Brothers', 1),
#  ('Barkaat Foods, LLC', 1),
#  ("Barron's Creek Beef Jerky", 1),
#  ("Barry's Barbeque", 1),
#  ('Bartels Farms', 1),
#  ('Bartels Packing', 1),
#  ('Bas Foods Inc.', 1),
#  ('Bastan Corporation', 1),
#  ('Bateman', 1),
#  ('Batesville Cold, Inc.', 1),
#  ('Baton Rouge Shrimp Company', 1),
#  ('Battaglia Distributing Co Inc', 1),
#  ('Battistoni Italian Specialty Meats, LLC', 1),
#  ("Bauman's Butcher Block", 1),
#  ('Bavaria Sausage Kitchen, Inc.', 1),
#  ('Bavarian Meat Products', 1),
#  ('Bay Valley Foods', 1),
#  ('Bay View Packing Co.', 1),
#  ('Bayou Barataria Foods, LLC', 1),
#  ('BD & K Foods, Inc.', 1),
#  ('BDC Properties/Construction, Inc.', 1),
#  ('Bear Creek Smokehouse', 1),
#  ('Beatrice Meat Company LLC', 1),
#  ('Beaver Meadow Road LLC', 1),
#  ('Beaver Street Fisheries Inc', 1),
#  ('Bee Bee Farms LLC', 1),
#  ('Beech-Nut Nutrition Corporation', 1),
#  ('Beef Burger Corp.', 1),
#  ('Beef International Inc.', 1),
#  ('Beef Jerky Unlimited', 1),
#  ('Beef Products, Inc.', 3),
#  ('Beef, Inc.', 1),
#  ('BEF Foods, Inc.', 2),
#  ('Behrmann Meat & Processing, Inc.', 1),
#  ('BelCampo Butchery', 1),
#  ('BelGioioso Cheese Inc.', 1),
#  ('Bell Brands LLC', 1),
#  ('Bell Foods, LLC', 1),
#  ('Bell Tasty Foods Inc', 1),
#  ('Bella Bella Gourmet Foods, LLC', 1),
#  ('Bellingham Cold Storage', 2),
#  ('Bellisio Foods, Inc.', 2),
#  ("Belly's Take-N-Bake Foods, LLC", 1),
#  ('Belmont Sausage Company', 1),
#  ('Beltex Corporation', 2),
#  ('Bemar Snacks Inc.', 1),
#  ('Bemka Corporation', 1),
#  ('Ben-Lee Processing Inc.', 1),
#  ('Ben E. Keith Company', 1),
#  ('Bende & Son Salami Co. Inc.', 1),
#  ('Benedetti Farms', 1),
#  ("Benner's Butcher Shoppe, LLC", 1),
#  ("Benny's Pork Skins", 1),
#  ('Bergen Wholesale Meats', 1),
#  ('Berger Wholesale Meat Co.', 1),
#  ('Berghorst Farms', 1),
#  ('Berix Coffee Deli LLC', 1),
#  ('Berk Lombardo Pkg. Co. Inc.', 1),
#  ('Berks Packing Co., Inc.', 1),
#  ('Berkshire Refrigerated Warehouse', 1),
#  ('Berkshire Refrigerated Warehousing, LLC', 1),
#  ('Bern Meat Plant', 1),
#  ("Bernatello's Pizza, Inc.", 2),
#  ('Bernthal Packing Inc.', 1),
#  ('Berry & Sons Rababeh Isl Slau', 1),
#  ('Berry Veal Corp.', 1),
#  ('Bert Hazekamp & Son Inc.', 1),
#  ('Bert Posess Inc', 1),
#  ('Best Buy Export LLC', 1),
#  ('Best Chicago Meat Co, LLC', 1),
#  ('Best Choice Meats', 1),
#  ('Best Express Foods, Inc.', 1),
#  ('Best Provision Co., Inc.', 1),
#  ('Best Value Food Products', 1),
#  ('Bestway Sandwiches Inc.', 1),
#  ('Bethlehem Sausage Works Inc.', 1),
#  ('Better Baked Foods of Erie, LLC', 1),
#  ('Better Baked Foods, Inc', 1),
#  ('Better Business - - - Better Foods', 1),
#  ('Better Meat Inc.', 1),
#  ('Beverly Processing, Inc.', 1),
#  ('Bianco & Son Inc.', 1),
#  ("Bickel's Snack Foods Inc.", 1),
#  ('Bierig Brothers Inc.', 1),
#  ("Bierly's Meat Market", 1),
#  ('Big A Meatball Company', 1),
#  ('Big Boy Food Group LLC', 1),
#  ('Big Chef', 1),
#  ('Big Dog Meats LLC', 1),
#  ('Big Easy Foods Louisiana Cuisine', 1),
#  ('Big Meat, LLC', 1),
#  ('BIG RED FARMS', 1),
#  ('Bighams Ham Company', 1),
#  ("Bill's Meat Market", 1),
#  ('Bill Newsome Hams', 1),
#  ('Bill Newsomes Hams', 1),
#  ('Biltong USA', 1),
#  ("Bimmy's Food Made With Love", 1),
#  ("Bingman's Packing", 1),
#  ("Binkert's Meat Products, LLC", 1),
#  ('Birchwood Foods', 1),
#  ('Birdsboro Kosher Farms Corp.', 1),
#  ('BiRite Foodservice Distributors', 1),
#  ('Birmingham Dreamland, Inc.', 1),
#  ("BJ's Wholessale Club", 1),
#  ('BKBG Enterprises', 1),
#  ('Black Jack Beef Jerky', 1),
#  ('Black Pearl Platinum Brand LLC', 1),
#  ('Blackberry Farm', 1),
#  ('Blackhawk Specialty Foods', 1),
#  ("Blake's Turkey Farm", 1),
#  ('Blakent Brands, LLC', 1),
#  ('Blalock Meat Processing', 1),
#  ('Blalock Meats', 1),
#  ('Bland Correctional Center', 1),
#  ('Blankenship Farms Meat Processing', 1),
#  ('Blessed Meat, Inc.', 1),
#  ('Bleu Blanc Rouge', 1),
#  ("Bloemer's Food Sales Co.", 1),
#  ('Bloom-N-Egg Farm', 1),
#  ('Bloomfield Food, Inc.', 1),
#  ('Blossom Foods, LLC', 1),
#  ('Blount Fine Foods', 1),
#  ('Blount Fine Foods Corp.', 1),
#  ('Blount Seaford Corporation', 1),
#  ('Blue & Gold Sausage Co.', 1),
#  ('Blue Chip Group, Inc', 1),
#  ('Blue Frog Foods LLC', 1),
#  ('Blue Grass Provision Company, Inc.', 1),
#  ('Blue Line Distributing', 1),
#  ('Blue Line Food Service Distribution', 1),
#  ('Blue Mountain Meats, Inc.', 1),
#  ('BLUE RIBBON MEAT CO', 1),
#  ('Blue Ridge Meats of Front Royal', 1),
#  ('Blue Star Meat Corp.', 1),
#  ('Blue Valley Meats, LLC', 1),
#  ('BMC Cali, Inc.', 1),
#  ('Bo-Bo Poultry Market Inc', 1),
#  ('Bo Kho Saigon Beef Jerky Company Inc.', 1),
#  ("Boar's Head Provision Co, Inc.", 2),
#  ("Boar's Head Provisions Co., Inc.", 3),
#  ("Bob's Better Beef, Inc.", 1),
#  ('Bob Evans Farms Inc.', 1),
#  ("Bobby Salazar's Food Products, Inc.", 1),
#  ('Boe Farms', 1),
#  ('Boesl Packing Co., Inc.', 1),
#  ("Boja's Foods, Inc.", 1),
#  ('Bolder Enterprises', 1),
#  ('Bolke-Miller Company', 1),
#  ('Bon Pate LLC', 1),
#  ('Bon Ton Food Service', 1),
#  ('Bonavista foods Inc.', 1),
#  ('Bonne Terre Meat Company', 1),
#  ('Bonneville Meats', 1),
#  ('BONOLLO PROVISIONS CO., INC.', 1),
#  ("Boone's Abattoir, Inc.", 1),
#  ('Border View Foods Inc.', 1),
#  ('Borenstein Caterers Inc.', 1),
#  ('Boston Brisket Company Inc.', 1),
#  ('Boston Salads and Provisions Company Inc.', 1),
#  ('Boston Sausage Co', 1),
#  ('Bostrom Farms Livestock and Meats', 1),
#  ('Bot N Bot', 1),
#  ('Boulder Organic Foods LLC', 1),
#  ('Bourgeois Smokehouse, LLC', 1),
#  ("Boutte's Boudin", 1),
#  ("Bowman's Butcher Shop, LLC", 1),
#  ('Bowman & Landes Turkeys, Inc.', 1),
#  ("Boyd's Wholesale Meats", 1),
#  ('Boyd Specialties LLC', 1),
#  ("Boyle's Famous Corned Beef Co.", 1),
#  ('BPT Products Inc.', 1),
#  ('Braaitime LLC', 1),
#  ("Bradley's Country Store", 1),
#  ('Brakebush Brothers, Inc.', 2),
#  ('Brakebush Irving, Inc.', 1),
#  ('Brand Aromatics Inc', 1),
#  ('Brandy Meats, Inc.', 1),
#  ('Brasstown Beef, LLC', 1),
#  ('Braunger Foods, LLC', 1),
#  ('Bravo Foods and Bakery, LLC', 1),
#  ('Bread and Chocolate Inc', 1),
#  ("Brenneman's Meat Market Inc", 1),
#  ('Brett Anthony Foods', 1),
#  ('Brewer Meats', 1),
#  ('Briden Foods / Shannons Deli Meats', 1),
#  ('Bridgford Foods of Illinois', 1),
#  ('Bridgford Foods of North Carolina', 1),
#  ('Bright Oak Meats, Inc.', 1),
#  ('Brimhall Foods Company Inc.', 1),
#  ('Brinkman Turkey Farms, Inc.', 1),
#  ('Bristol Beef', 1),
#  ("Britt's Slaughterhouse", 1),
#  ('Broadleaf Inc.', 2),
#  ('Broadway Corn Beef Co., Inc.', 1),
#  ("Brock's Esto Meat Processing", 1),
#  ('Broken Arrow Ranch, Inc.', 1),
#  ('Bromley Meats', 1),
#  ('Bronson Locker', 1),
#  ('Brooke Industries, Inc.', 1),
#  ('Brooklyn Meat Sales', 1),
#  ('Brooks Meats, Inc.', 1),
#  ('Brooksville Meat Fabrication Center, Inc.', 1),
#  ('Brookwood Farms', 1),
#  ('Broomes Poultry', 1),
#  ('Brothee LLC', 1),
#  ("Brother's Custom Processing Inc.", 1),
#  ('Brother & Sister Food Services Inc.', 1),
#  ('Brother and Sister Food Services Inc.', 1),
#  ('Brothers Meats Processors, LLC', 1),
#  ("Brown's Meat Locker", 1),
#  ('Brown Packing Co., Inc.', 1),
#  ('Bruce Packing Company', 2),
#  ('BrucePac - Durant', 1),
#  ('Brush Meat Processors LLC', 1),
#  ('Brushy Prairie Packing, Inc.', 1),
#  ("Bryan's Meat Inc.", 1),
#  ("Bryant's Meat Inc", 1),
#  ('Bubba Foods, LLC', 1),
#  ('Bucher Meats', 1),
#  ('Buckhead Beef', 1),
#  ('Buckhead Beef Charlotte', 1),
#  ('Buckhead Beef Northeast', 1),
#  ('Buckhead Beef of Florida', 1),
#  ('Buckhead Beef Rhode Island', 1),
#  ("Buddy's Kitchen, Inc.", 1),
#  ('Buedel Fine Meats and Provisions', 1),
#  ('Bueno Foods', 1),
#  ('Buffalo SAV, Inc.', 1),
#  ('Bum Foods LLC', 1),
#  ('Bumble Bee Seafoods LLC', 1),
#  ('Buona Vita Inc.', 1),
#  ('Bupik Inc.', 1),
#  ("Burger's Ozark Country Cured", 1),
#  ('Burger Maker Inc.', 1),
#  ('Burgundy Pasture Beef, LP', 1),
#  ('Burk Ridge Farms', 1),
#  ('Burk Ridge Farms, LLC', 1),
#  ('Burke Marketing Corporation', 1),
#  ('Burnett & Son Meat Co., Inc.', 1),
#  ('Burnette Foods Inc.', 1),
#  ('Burris Logistics', 3),
#  ('Burris Retail Logistics', 1),
#  ('Burrito Kitchens Enterprises', 1),
#  ("Burt's Meat & Poultry", 1),
#  ('Busetto Foods', 1),
#  ('Bush Brothers Provision Co., Inc.', 1),
#  ('Busseto Foods Inc', 1),
#  ('Busseto Foods, Inc.', 1),
#  ("Butch's Original Pizza, Inc.", 1),
#  ('Butcher Block & Smokehouse, Inc.', 1),
#  ('Butterball LLC', 1),
#  ('Butterball, LLC', 5),
#  ('Butterfield Foods Company', 1),
#  ('Butterfield Foods, LLC', 1),
#  ('Buzz Products, Inc.', 1),
#  ('By George, Inc.', 1),
#  ('Byerly Foods International, Inc.', 1),
#  ('Bylada Foods LLC', 1),
#  ('Byron Center Wholesale Meats, Inc.', 1),
#  ('C & C Processing, Inc.', 1),
#  ('C & L Foods, Inc.', 1),
#  ('C & S Poultry', 1),
#  ('C & W Meat Packers', 1),
#  ('C&C Meat Sales, Inc.', 1),
#  ('C&F Meats', 1),
#  ('C&F Packing Company', 1),
#  ('C&H Meat Co.', 1),
#  ('C&H Meat Company', 1),
#  ('C&H Veal Co.', 1),
#  ('C&J Tendermeat Co., Inc.', 1),
#  ('C&K Unlimited, Inc.', 1),
#  ('C&S Wholesale Meat Co.', 1),
#  ('C. Roy, Inc.', 1),
#  ('C. W Brown Foods Inc', 1),
#  ('C.R. Meats', 1),
#  ('Cabal Sausage Company, LLC', 1),
#  ('Cabin Hollow Butcher Shop, Inc', 1),
#  ('Cabool Kountry Meats, LLC', 1),
#  ("Cabrera's Spanish Sausages", 1),
#  ('Cabrito Market, Inc.', 1),
#  ('Cacique, Inc.', 1),
#  ("Caesar's Pasta, LLC", 1),
#  ('CAFE SPICE GCT, INC.', 1),
#  ('Caggiano Co.', 1),
#  ('CaiE Foods', 1),
#  ('Caine Warehousing LTD', 1),
#  ('Caito Foods, Inc.', 1),
#  ('Cajun Original Foods, Inc.', 1),
#  ('Cajun Specialty Meats', 1),
#  ('Cal Poly Meats', 1),
#  ('Calabro Cheese Corporation', 1),
#  ('Caldwell Farms', 1),
#  ('Caledonia Packing LLC', 1),
#  ("Calif. Qi Li's Braised Chicken LLC", 1),
#  ('California Farms Meat Company Inc.', 1),
#  ('California Jerky Factory, Inc.', 1),
#  ('California Ranch Food Company Inc.', 1),
#  ('California Sausage', 1),
#  ('California State University, Chico', 1),
#  ('Calihan Pork Processors', 1),
#  ('Callaway Packing, Inc.', 1),
#  ('Callicrate Cattle Co.', 1),
#  ('Calumet Diversified Meats Inc.', 1),
#  ("Camacho's Food Processing", 1),
#  ('Cambridge Packing Co', 1),
#  ('Camden Port Services Inc.', 1),
#  ('Camden Port Services, Inc.', 1),
#  ('Cameco Inc.', 1),
#  ('Camellia General Provision Co.', 1),
#  ("Cameron's British Foods Inc", 1),
#  ('Camino Real Foods, Inc.', 1),
#  ('Campbell Soup Company', 2),
#  ('Campbell Soup Supply Co., LLC', 1),
#  ('Campbell Soup Supply Company', 1),
#  ('Campbell Soup Supply Company L.L.C.', 1),
#  ('Campo Lindo Farms', 1),
#  ('Campofrio Food Group - America, Inc.', 1),
#  ('Campos Foods LLC', 1),
#  ('Cangialosi Specialty Sausage Company, Inc.', 1),
#  ("Canino's Sausage Company Co., Inc.", 1),
#  ('CANNON COLD STORAGE', 1),
#  ('Canteen', 1),
#  ('Canteen/Covenco', 1),
#  ('Canyon Foods Dist Inc', 1),
#  ('Cape Code Cafe Foods', 1),
#  ('Capitol Cold Storage & Distribution', 1),
#  ('Capitol Sausage & Provisions Inc', 1),
#  ('Capitol Wholesale Meats, Inc.', 1),
#  ('Capri Restaurant', 1),
#  ("Captain's Fine Foods, LLC", 1),
#  ("Captain Ken's Foods, Inc.", 1),
#  ('Carando Gourmet Frozen Foods Corporation', 1),
#  ('Cargill', 1),
#  ('Cargill Food Dist.', 1),
#  ('Cargill Food Distribution', 3),
#  ('CARGILL FOOD DISTRIBUTION', 1),
#  ('Cargill Fresno Grind', 1),
#  ('Cargill Kitchen Solutions, Inc.', 5),
#  ('Cargill Meat Solution Corporation', 2),
#  ('Cargill Meat Solutions', 8),
#  ('CARGILL MEAT SOLUTIONS', 1),
#  ('Cargill Meat Solutions Corp.', 3),
#  ('Cargill Meat Solutions Corpora', 1),
#  ('Cargill Meat Solutions Corporation', 6),
#  ('Cargill Meats Solutions Corporation', 1),
#  ('Cargill Value Added Meats', 1),
#  ('Cargill, Inc', 1),
#  ('Cargo International Consolidators Inc.', 1),
#  ('Caribbean Breeze Frozen Foods Corp.', 1),
#  ('Caribbean Food Delights', 1),
#  ('Caribbean Snacks & More', 1),
#  ("Carl's Boned Chicken, Inc.", 1),
#  ('Carl Buddig & Company', 1),
#  ('Carl Buddig and Co', 1),
#  ('Carl Buddig and Company', 1),
#  ('Carl Streit & Son Co.', 1),
#  ('Carl Venezia Meats', 1),
#  ("Carla's Pasta Inc", 1),
#  ("Carle's Bratwurst, Inc.", 1),
#  ("Carlie C's Operation Center, Inc.", 1),
#  ("Carlotta's Kitchen LLC", 1),
#  ('Carlson Meat Processing, Inc.', 1),
#  ('Carlton Foods, Llc', 1),
#  ('Carlton Packing Company', 1),
#  ('Carnegie Deli Inc.', 1),
#  ('Carnival Brands', 1),
#  ('Carnivore Market', 1),
#  ('Carnivore Meat Company LLC', 1),
#  ('Carolina Catering dba Sky Caterers, Inc.', 1),
#  ('Carolina Fresh Foods', 1),
#  ('Carolina Packers, Inc.', 1),
#  ('Carolina Pride Foods, Inc.', 1),
#  ('Carrington Foods Inc', 1),
#  ("Carso's Pasta Company", 1),
#  ('Carters Creative Catering', 1),
#  ('Casa Blanca Santa Fe, LLC', 1),
#  ('Casa Di Carfagna', 1),
#  ('Casanova Market Inc.', 1),
#  ('Cascade Food Corp.', 1),
#  ('Cascade Wholesale Meats', 1),
#  ('Cascioppo Brothers Meats, Inc.', 1),
#  ('Case Farms of North Carolina, Inc.', 1),
#  ('Case Farms of Ohio, Inc', 1),
#  ('Case Farms Processing, Inc', 1),
#  ('Case Farms Processing, Inc.', 1),
#  ('Case Pork Roll Company Inc.', 1),
#  ('Casi di Pasta, Inc.', 1),
#  ('Casing Associates LLC', 1),
#  ('Casselton Cold Storage Inc.', 1),
#  ('Cassinelli Food Products, Inc.', 1),
#  ('Castelo Cold Storage LLC', 1),
#  ('Castillo Brothers Enterprises Inc.', 1),
#  ('Castle Rock Meats, Inc.', 1),
#  ('Castro Foods Wholesale, Inc', 1),
#  ('Catalina Finer Meat Corp.', 1),
#  ('Catelli Brothers Inc.', 1),
#  ('Cathay Foods Co.', 1),
#  ('Cattaneo BBQ Service', 1),
#  ('Cattaneo Bros, Inc.', 1),
#  ('Cauldron Soups LLC', 1),
#  ('Caver Meats', 1),
#  ('Caviness Beef Packers, Ltd.', 2),
#  ('CB Foods Inc.', 1),
#  ('CC Kitchens LLC', 1),
#  ('ccb Packaging, Inc.', 1),
#  ('CCP Poultry & Meat Corp.', 1),
#  ('Cedar Creek Beef Jerky L.L.C.', 1),
#  ('Cedar Valley Services', 1),
#  ('Cedar Valley Services, Inc.', 1),
#  ('Cedarlane Natural Foods, Inc.', 4),
#  ('Cedrick Inc.', 1),
#  ('Celebrity Foods Division of Atalanta Corporation', 1),
#  ('Center Cut Meats LLC', 1),
#  ('Center for Advancement of Meat Production and Processing', 1),
#  ('Center Fresh Egg Farm L.L.P.', 1),
#  ('Center of Innovation', 1),
#  ('Center Road Enterprises', 1),
#  ('Central Cold Storage', 1),
#  ('Central Falls Provisions Co., Inc.', 1),
#  ('Central Illinois Poultry Processing, LLC', 1),
#  ('Central KY Custom Meats, Inc.', 1),
#  ('Central Maine Meats', 1),
#  ('Central Maine Meats, LLC', 1),
#  ('Central Meat & Provisions', 1),
#  ('Central Meat and Provision Co', 1),
#  ('Central Meat Packing', 1),
#  ('Central Meat Processors, Inc.', 1),
#  ('Central Missouri Meat & Sausage', 1),
#  ('Central Oregon Butcher Boys', 1),
#  ('Central Snacks, Inc.', 1),
#  ('Central Storage & Warehouse Co', 1),
#  ('Central Storage & Warehouse Co.', 1),
#  ('Central Storage and Warehouse Co., Inc.', 1),
#  ('Central Valley Meat Co., Inc.', 1),
#  ('Centrum Valley Farms L.L.P.', 1),
#  ('Century Frozen Foods, LLC', 1),
#  ('Century Harvest Farms', 1),
#  ('Century Oak Packing Company', 1),
#  ('Century Packing Corp.', 1),
#  ('Cepas, Inc', 1),
#  ('Certified Meat Products', 1),
#  ('Cervantes Distributor Inc.', 1),
#  ('Cesina Sausage Co.', 1),
#  ('Chair City Meats Inc.', 1),
#  ("Chairman's Foods LLC", 1),
#  ('Chalet Market Inc.', 1),
#  ('Chambersburg Cold Storage Inc.', 1),
#  ('Chamblee Meats & Supplies', 1),
#  ('Champ Meatball Company Inc.', 1),
#  ('Champion Foods LLC', 1),
#  ('Champion Gourmet Products', 1),
#  ('Champion Pizza', 1),
#  ('Champlain Beef Company Inc', 1),
#  ('Chandler Foods, Inc.', 1),
#  ('Chang Tuh', 1),
#  ("Chapa's Fried Pork Skins", 1),
#  ("Chaparro's Tamales", 1),
#  ('Chappell Hill Sausage Company', 1),
#  ('Charles Austin Holdings, LLC', 1),
#  ('Charles Ritter Inc', 1),
#  ("Charley & Son's", 1),
#  ("Charlie's Meat Market", 1),
#  ("Charlie's Produce", 1),
#  ('Chaudhry Meat Company, Inc.', 1),
#  ('Che Pibe Gourmet Products', 1),
#  ('Chee Foo International Inc', 1),
#  ('Cheese Pleasers Inc.', 1),
#  ("Chef's Choice Cash & Carry Food Distribution Inc", 1),
#  ("Chef's Delight Packing Co, Inc", 1),
#  ("Chef's Requested Foods, Inc.", 1),
#  ('Chef Charles Catering Company', 1),
#  ('Chef Creations LLC', 1),
#  ('Chef John Folse and Company', 1),
#  ('Chef Minute Meals Inc', 1),
#  ('Chef One Corporation', 2),
#  ('Chefs Commissary', 1),
#  ('Chelsea Food Services', 1),
#  ('Cheney Bros. Inc.', 1),
#  ('Cheney OFS, Inc.', 1),
#  ('Chenoa Locker, Inc.', 1),
#  ('Cher-Make Sausage Company', 1),
#  ('Cheraw Packing Plant, Inc.', 1),
#  ('Cherry Meat Company', 1),
#  ('Cherry Meat Packers, Inc.', 1),
#  ('Chez Dalida', 1),
#  ('Chia Hsiung Corp.', 1),
#  ('Chicago Cold Storage', 1),
#  ('Chicago Meat Authority', 2),
#  ('Chicago Seafood & Restaurant Supply Inc.', 1),
#  ('Chicharon Poblano LLC', 1),
#  ('Chicharrones J&J', 1),
#  ('Chicharrones Pacheco', 1),
#  ('Chick-A-Ray Poultry & Egg Co., Inc.', 1),
#  ('Chickasha Meat Company, LLC', 1),
#  ('Chicopee Provision Company Inc.', 1),
#  ("Chieffo's Frozen Foods", 1),
#  ('Chihade International, Inc.', 1),
#  ('Childers Meat Company', 1),
#  ('Chillicothe Meats LLC', 1),
#  ('Chinamerica Food Manufacture, Inc.', 1),
#  ('Chinese Spaghetti Factory', 1),
#  ('Chino Valley Ranchers', 1),
#  ('Chip Steak & Provision', 1),
#  ("Chirpy's Barbecue", 1),
#  ('Chisesi Brothers Meat Packing Company', 1),
#  ('Choice Canning Company Inc.', 1),
#  ('Choice Food Products Inc.', 1),
#  ('Choice Products USA', 1),
#  ('Chorizo de San Manuel Inc.', 1),
#  ('Chorizo Janitzio, Inc.', 1),
#  ('Chorizo Selecto', 1),
#  ('Chow Bros. Whsle Meats Co Inc', 1),
#  ('Christian Aid Ministries', 2),
#  ('Chungs Products LP', 1),
#  ('Chunwei, Inc.', 1),
#  ('Church of Jesus Christ of Latter Day Saints', 1),
#  ('Ciales Poultry, Inc.', 1),
#  ('Cibao Meat Products Inc.', 1),
#  ('CieBend Inc.', 1),
#  ('Cifelli & Sons, Inc', 1),
#  ("Cimpl's, Inc.", 1),
#  ('Circle M Meats LLC', 1),
#  ('Circle Pines Sausage Haus, Inc.', 1),
#  ('Circle R Beef Inc.', 1),
#  ('Circle S Farms', 1),
#  ('Circle S Groom Sausage LLC', 1),
#  ('Cisneros Packing Company, Inc.', 1),
#  ('City Beef Company Inc', 1),
#  ('City Foods, Inc.', 1),
#  ('City Line Distributors Inc.', 1),
#  ('City Meat Company of Tampa Inc.', 1),
#  ('City Meat Steak Co., Inc.', 1),
#  ('CJ Foods Manufacturing Corporation', 1),
#  ("Clair D Thompson & Son's Inc", 1),
#  ("Clark's Poultry and Seafood", 1),
#  ('Clark Meat Science Laboratory', 1),
#  ('Clarmil Manufacturing Corp.', 1),
#  ("Claro's Italian Markets, Inc.", 1),
#  ('Classic Delight, Inc.', 1),
#  ('Classic Foods, LP', 1),
#  ('Classic Recipe Chili, Inc.', 1),
#  ('CLASSIC SEAFOOD GROUP, INC.', 1),
#  ('Claus Meats, Inc.', 1),
#  ('Clausen Meat Company Inc.', 1),
#  ('Claymont Food Co.', 1),
#  ('Claysburg Pizza Fundraisers', 1),
#  ("Clem's Custom Cut Meats", 1),
#  ('Clemens Food Group, LLC', 2),
#  ('Clint & Sons Beef Jerky', 1),
#  ('Clipper Foods', 1),
#  ('Clougherty Packing Inc.', 1),
#  ('Clougherty Packing LLC', 2),
#  ('Cloverdale Foods Co.', 1),
#  ('Cloverleaf Cold Storage', 11),
#  ('Cloverleaf Cold Storage Cherokee', 1),
#  ('Cloverleaf Cold Storage Co', 1),
#  ('Cloverleaf Cold Storage Co.', 4),
#  ('Cloverleaf Cold Storage Company', 1),
#  ('Cloverleaf Cold Storage Le Mars', 1),
#  ('CLS Gourmet CL Saigon Food Company', 1),
#  ('Club House Market, Inc', 1),
#  ('CLW Foods, LLC', 1),
#  ('Clydes Sausage, Inc.', 1),
#  ('CM & R, Inc.', 1),
#  ('Coast Packing Company', 1),
#  ('Coastal Pacific Food Distributors', 1),
#  ('Coastal Processing, LLC', 1),
#  ('Coblentz Distributing, Inc', 1),
#  ("Coffaro's Custom Butchering", 1),
#  ('Cold Chain Integrity', 1),
#  ('Cold Zone, Inc.', 1),
#  ('ColdPoint Logistics Warehouse, LLC', 1),
#  ('College of the Ozarks', 1),
#  ('Colley Crafted Snack Foods', 1),
#  ("Colliey's Crafted Snacks", 1),
#  ('Colorado Boxed Beef Co.', 1),
#  ('Colorado Homestead Ranches, Inc.', 1),
#  ('Colorado Premium Cold Storage', 1),
#  ('Colorado Premium Foods', 2),
#  ('Colosimo Sausage Plant', 1),
#  ('Columbia Empire Meat Co., Inc.', 1),
#  ('Columbia Meats. Inc.', 1),
#  ('Columbia Packing Co., Inc.', 1),
#  ('Columbus Manufacturing Inc.', 2),
#  ...]

# %% [markdown]
# Scrolling through the results reveals a number of cases in which a company's name is spelled several different ways. For e.g., notice the entries for the Armour-Eckrich brand.
#
# ![6.png](attachment:6.png)
#
# At least four different spellings are shown for seven establishments owned by the same company. It would help to standardize the names so all of the items counted or summed are grouped properly in case we perform any aggregation by company.

# %% [markdown]
# #### Checking for Malformed Values using *length()*
# It's important to check for unexpected values in a column that should be consistently formatted. For e.g., each entry in the `zip` column in the `meat_poultry_egg_inspect` table should be formatted in the style of U.S. zip codes with five digits. Some codes in our data set that start with 0 have lost the integer during conversion from one file format to another.
# `length()` is a string function that counts the number of characters in a string. We combine `length()`, `count()` and `GROUP BY` to determine how may rows have five characters in the `zip` field and how many have a value other than five. To make it easy to scan the results, we use `length()` in the `ORDER BY` clause.

# %%
# %%sql
# SELECT length(zip), count(*) AS length_count
# FROM meat_poultry_egg_inspect
# GROUP BY length(zip)
# ORDER BY length(zip) ASC;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 3 rows affected.
# [(3, 86), (4, 496), (5, 5705)]

# %% [markdown]
# There are 496 zip codes that are four characters long and 86 are three characters long, which means these numbers originally had one and two leading zeros, respectively.
# Using the `WHERE` clause, we can check which states these shortened zip codes correspond to.

# %%
# %%sql
# SELECT st, count(*) AS st_count
# FROM meat_poultry_egg_inspect
# WHERE length(zip) < 5
# GROUP BY st
# ORDER BY st ASC;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 9 rows affected.
# [('CT', 55),
#  ('MA', 101),
#  ('ME', 24),
#  ('NH', 18),
#  ('NJ', 244),
#  ('PR', 84),
#  ('RI', 27),
#  ('VI', 2),
#  ('VT', 27)]

# %% [markdown]
# The result is what we'd expect. Usually the states in the Northeast region of the U.S. are where the zip codes start with 0.
#
# So far, we need to correct the following issues in our data set:
# - Missing values for three rows in the `st` column
# - Inconsistent spelling of at least one company's name
# - Inaccurate zip codes due to file conversion

# %% [markdown]
# ---
# ### Restoring Missing Values
#
# Earlier we found three rows that don't have a value in the `st` column. We can find the values we need with a quick online search.

# %%
# %%sql
# UPDATE meat_poultry_egg_inspect
# SET st = 'MN'
# WHERE est_number = 'V18677A';
#
# UPDATE meat_poultry_egg_inspect
# SET st = 'AL'
# WHERE est_number = 'M54319+P45319';
#
# UPDATE meat_poultry_egg_inspect
# SET st = 'WI'
# WHERE est_number = 'M263A+P263A+V263A';
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 1 rows affected.
# 0 rows affected.
# 1 rows affected.
# []

# %% [markdown]
# ---
# ### Updating Values for Consistency
#
# We discovered several cases where a single company’s name
# was entered inconsistently. If we want to aggregate data by company name,
# such inconsistencies will hinder us from doing so.
# We can standardize the spelling of a company name by using an `UPDATE` statement. To avoid tampering with the original data, we'll copy the names in `company` into a new column, and work in the new column.

# %%
# %%sql
# ALTER TABLE meat_poultry_egg_inspect
#     ADD COLUMN company_standard varchar(100);
#
# UPDATE meat_poultry_egg_inspect
# SET company_standard = company;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# Done.
# 6287 rows affected.
# []

# %% [markdown]
# Let's say we want any name in company that contains the string `Armour` to appear in `company_standard` as `Armour-Eckrich Meats`. We can update all the rows matching the string `Armour` by using a `WHERE` clause.

# %% [markdown]
# ![9.png](attachment:9.png)
#
# You can see how the names have now been standardized. If we want to standardize other company
# names in the table, we would create an `UPDATE` statement for each case.

# %% [markdown]
# ---
# ### Repairing ZIP Codes using Concatenation
#
# To fix our values in the zip codes column, we'll use `UPDATE` in conjunction with the double-pip string operator `||`, which performs concatenation. Concatenation combines two or more string or non-string values into one.

# %%
# %%sql
# UPDATE meat_poultry_egg_inspect
# SET zip = '00' || zip
# WHERE st IN ('PR', 'VI') AND length(zip) = 3;
#
# UPDATE meat_poultry_egg_inspect
# SET zip = '0' || zip
# WHERE st IN('CT','MA','ME','NH','NJ','RI','VT') AND length(zip) = 4;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 86 rows affected.
# 496 rows affected.
# []

# %% [markdown]
# Let's check again with our earlier query.

# %%
# %%sql
# SELECT length(zip), count(*) AS length_count
# FROM meat_poultry_egg_inspect
# GROUP BY length(zip)
# ORDER BY length(zip);
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 1 rows affected.
# [(5, 6287)]

# %% [markdown]
# All rows now have a five-digit zip code.

# %% [markdown]
# ---
# ### Updating Values Across Tables
#
# Let's say we're setting an inspection date for each of the companies in our table. We want to do this by U.S. regions, such as Northeast, Pacific, and so on, but those regional designations don't exist in our table. However, we can add a table from another data set that contains matching `st` state codes. Let's begin with the New England region.
# We'll create a new table called `state_regions`.

# %%
# %%sql
# CREATE TABLE state_regions (
#     st varchar(2) CONSTRAINT st_key PRIMARY KEY,
#     region varchar(20) NOT NULL
# );
#
# COPY state_regions
# FROM 'C:\Users\Public\postgresql_practice\practical-sql-master\Chapter_09\state_regions.csv'
# WITH (FORMAT CSV, HEADER, DELIMITER ',');
# Out:
#  * postgresql://postgres:***@localhost/analysis
# Done.
# 56 rows affected.
# []

# %%
# %%sql
# SELECT * FROM state_regions;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 56 rows affected.
# [('AK', 'Pacific'),
#  ('AL', 'East South Central'),
#  ('AR', 'West South Central'),
#  ('AS', 'Outlying Area'),
#  ('AZ', 'Mountain'),
#  ('CA', 'Pacific'),
#  ('CO', 'Mountain'),
#  ('CT', 'New England'),
#  ('DC', 'South Atlantic'),
#  ('DE', 'South Atlantic'),
#  ('FL', 'South Atlantic'),
#  ('GA', 'South Atlantic'),
#  ('GU', 'Outlying Area'),
#  ('HI', 'Pacific'),
#  ('IA', 'West North Central'),
#  ('ID', 'Mountain'),
#  ('IL', 'East North Central'),
#  ('IN', 'East North Central'),
#  ('KS', 'West North Central'),
#  ('KY', 'East South Central'),
#  ('LA', 'West South Central'),
#  ('MA', 'New England'),
#  ('MD', 'South Atlantic'),
#  ('ME', 'New England'),
#  ('MI', 'East North Central'),
#  ('MN', 'West North Central'),
#  ('MO', 'West North Central'),
#  ('MP', 'Outlying Area'),
#  ('MS', 'East South Central'),
#  ('MT', 'Mountain'),
#  ('NC', 'South Atlantic'),
#  ('ND', 'West North Central'),
#  ('NE', 'West North Central'),
#  ('NH', 'New England'),
#  ('NJ', 'Middle Atlantic'),
#  ('NM', 'Mountain'),
#  ('NV', 'Mountain'),
#  ('NY', 'Middle Atlantic'),
#  ('OH', 'East North Central'),
#  ('OK', 'West South Central'),
#  ('OR', 'Pacific'),
#  ('PA', 'Middle Atlantic'),
#  ('PR', 'Outlying Area'),
#  ('RI', 'New England'),
#  ('SC', 'South Atlantic'),
#  ('SD', 'West North Central'),
#  ('TN', 'East South Central'),
#  ('TX', 'West South Central'),
#  ('UT', 'Mountain'),
#  ('VA', 'South Atlantic'),
#  ('VI', 'Outlying Area'),
#  ('VT', 'New England'),
#  ('WA', 'Pacific'),
#  ('WI', 'East North Central'),
#  ('WV', 'South Atlantic'),
#  ('WY', 'Mountain')]

# %% [markdown]
# Now let's add a column for inspection dates to the `meat_poultry_egg_inspect` table.

# %%
# %%sql
# ALTER TABLE meat_poultry_egg_inspect ADD COLUMN inspection_date date;
#
# UPDATE meat_poultry_egg_inspect inspect
# SET inspection_date = '2021-12-01'
# WHERE EXISTS (SELECT state_regions.region
#               FROM state_regions
#               WHERE inspect.st = state_regions.st
#                 AND state_regions.region = 'New England');
# Out:
#  * postgresql://postgres:***@localhost/analysis
# Done.
# 252 rows affected.
# []

# %%
# %%sql
# SELECT st, inspection_date
# FROM meat_poultry_egg_inspect
# GROUP BY st, inspection_date
# ORDER BY st;
# Out:
#  * postgresql://postgres:***@localhost/analysis
# 57 rows affected.
# [('AK', None),
#  ('AL', None),
#  ('AR', None),
#  ('AS', None),
#  ('AZ', None),
#  ('CA', None),
#  ('CO', None),
#  ('CT', datetime.date(2021, 12, 1)),
#  ('DC', None),
#  ('DE', None),
#  ('FL', None),
#  ('GA', None),
#  ('GU', None),
#  ('HI', None),
#  ('IA', None),
#  ('ID', None),
#  ('IL', None),
#  ('IN', None),
#  ('KS', None),
#  ('KY', None),
#  ('LA', None),
#  ('MA', datetime.date(2021, 12, 1)),
#  ('MD', None),
#  ('ME', datetime.date(2021, 12, 1)),
#  ('MI', None),
#  ('MN', None),
#  ('MO', None),
#  ('MP', None),
#  ('MS', None),
#  ('MT', None),
#  ('NC', None),
#  ('ND', None),
#  ('NE', None),
#  ('NH', datetime.date(2021, 12, 1)),
#  ('NJ', None),
#  ('NM', None),
#  ('NV', None),
#  ('NY', None),
#  ('OH', None),
#  ('OK', None),
#  ('OR', None),
#  ('PA', None),
#  ('PR', None),
#  ('RI', datetime.date(2021, 12, 1)),
#  ('SC', None),
#  ('SD', None),
#  ('TN', None),
#  ('TX', None),
#  ('UT', None),
#  ('VA', None),
#  ('VI', None),
#  ('VT', datetime.date(2021, 12, 1)),
#  ('WA', None),
#  ('WI', None),
#  ('WV', None),
#  ('WY', None),
#  (None, None)]

# %% [markdown]
# We can see that the inspection dates are filled for the states in the New England region.
# This way we can fill in dates for the other regions as well.

# %% [markdown]
# ---
